# %%
# Install the packages\
# %pip install requests openai~=1.10

# %%
import config
import json
import requests
import time
from openai import AzureOpenAI
from pathlib import Path
from typing import Optional

config_params = config.ConfigParameters()

# %%
azure_endpoint = config_params.azure_endpoint 
api_version = config_params.api_version 
aoai_api_key =  config_params.aoai_api_key 
bing_search_subscription_key = config_params.bing_search_subscription_key
bing_search_url = config_params.bing_search_url
deployment_name = config_params.deployment_name

# %%
def get_topevents(query) -> list:
    headers = {"Ocp-Apim-Subscription-Key": config_params.bing_search_subscription_key}
    params = {"q": query, "textDecorations": False}
    response = requests.get(config_params.bing_search_url, headers=headers, params=params)
    response.raise_for_status()
    search_results = response.json()
    output = []

    for result in search_results["webPages"]["value"]:
#         output.append({ "link": result["url"],"snippet": result["snippet"]})
         output.append({"title": result["name"], "link": result["url"], "snippet": result["snippet"]})

    return json.dumps(output)

def getLatLong(address):
    params = {
        'subscription-key': config_params.AZURE_MAPS_SUBSCRIPTION_KEY,
        'api-version': '1.0',
        'language': 'en-US',
        'query': address
    }

    response = requests.get('https://atlas.microsoft.com/search/address/json', params=params)
    data = response.json()

    try:
        lat = data['results'][0]['position']['lat']
        lon = data['results'][0]['position']['lon']
    except (IndexError, KeyError) as e:
        print(f'Error: {e}')
        return None

    return lat, lon

def weather (location,unit) -> list:
    lat, lon = getLatLong(location)
    print(f"Lat: {lat}, Lon: {lon}")
    url = "https://api.tomorrow.io/v4/weather/forecast?location=" + str(lat) + "," + str(lon) + "&apikey=" + config_params.TOMORROWIO_API_KEY
    payload = {}
    headers = {
    }
    response = requests.request("GET", url, headers=headers, data=payload)
    resp = json.loads(response.text)
    print(resp['timelines']["hourly"][0]["values"]["temperature"])
    output = []
    output.append({"content": "The weather in " + location + " " + str(resp['timelines']["hourly"][0]["values"]["temperature"]) + " " +  unit })

    return json.dumps(output)

# %%
get_topevents("What are the top events in Frisco today?")
# Out:
# '[{"title": "Things to Do in Frisco Today | Eventbrite", "link": "https://www.eventbrite.com/d/tx--frisco/events--today/", "snippet": "Sambuca 360 Dallas Stars Alumni vs SMU presented by \\"The Jarrell Company\\" Sat, Feb 3 \\u2022 7:30 PM Children\'s Health StarCenter Saturday Night Vibes at Ekko Lounge Sat, Feb 3 \\u2022 9:00 PM Ekko Lounge LATIN SATURDAY NIGHT Sat, Feb 3 \\u2022 9:00 PM Rockin\' Taco Bar, Main Street, Frisco, TX, USA Lets Cumbia Valentines Special Sat, Feb 3 \\u2022 6:00 PM"}, {"title": "Events in Frisco, TX | Visit Frisco", "link": "https://www.visitfrisco.com/events/", "snippet": "Plan Your Visit Home \\u00b7 Events Events Whether you\\u2019re interested in music festivals, sporting events, arts & culture events, holiday happenings, educational experiences or nightly live music, you\'ll find everything you need to know to plan your perfect getaway here."}, {"title": "Frisco Events Calendar - What to DO and Where to GO in Frisco, Texas", "link": "https://lifestylefrisco.com/frisco-events-calendar/", "snippet": "World of Barbie Tour Feb 7 @ 12:00 pm \\u2013 5:00 pm Pop-Up STEM: Tech Feb 7 @ 4:00 pm \\u2013 5:00 pm Blended: Parks & Arts Mixer Feb 7 @ 5:30 pm \\u2013 7:30 pm Valentine\\u2019s Sip & Stroll in The Star District Tickets Feb 7 @ 6:00 pm \\u2013 9:00 pm Cirque Du Soleil: Crystal Tickets Feb 7 @ 7:30 pm Feb 8 Thu AARP Tax Assistance: By Appointment Only"}, {"title": "What\'s happening in Frisco, TX. Today\'s events & festivals | WikiDo", "link": "https://www.wikido.com/us/tx/frisco", "snippet": "Sat 12/30 Common Threads: Kwanzaa Kwanzaa, the Swahili word for \' First Fruits\' is the name given to the annual observance developed by Maulana Karenga and celebrated by many since 1966. Kwanzaa begins on each year. Each day... Sat 12/30 @ 9:00 am Frisco, TX. Frisco Heritage Center \\"@en, TX.. Sun 12/31 The Glen Presents Studio 54 NYE Extravaganza"}, {"title": "Things To Do Near Frisco Today | Events Around Frisco Today - AllEvents.in", "link": "https://allevents.in/frisco/today", "snippet": "Events & Things To Do With Friends & Family in Frisco Today Explore the best events happening near Frisco today & tonight! From live music and theater performances to art exhibits and outdoor festivals, there\'s something for everyone to enjoy in Frisco. Discover new and exciting experiences & things to do in Frisco today! Today\'s Events in Frisco"}, {"title": "TOP 10 BEST Events This Weekend in Frisco, TX - Yelp", "link": "https://www.yelp.com/search?find_desc=events+this+weekend&find_loc=Frisco%2C+TX", "snippet": "Fun for the whole family.\\" Top 10 Best Events This Weekend in Frisco, TX - February 2024 - Yelp - Plano Art Fest, Plano Balloon Festival, Wildflower Arts & Music Festival, Taste Addison, Addison Oktoberfest, Comerica Center, Fortunata Winery, Credit Union of Texas Event Center, Laura E West, Aldeez Afribbean Restaurant."}, {"title": "Things To Do In Frisco TX | Visit Frisco Texas", "link": "https://www.visitfrisco.com/things-to-do/", "snippet": "Whether you call it f\\u00fatbol or soccer, cheer on FC Dallas at Toyota Stadium; catch a Frisco RoughRiders baseball game while floating the Lazy River, or watch the Dallas Cowboys practice and then tour their headquarters and practice facility at The Star. No matter which team you root for, Frisco is the ultimate destination for sports fans."}, {"title": "Frisco, TX - Events", "link": "https://lifestylefrisco.com/events/", "snippet": "Frisco hosts an array of annual events in Frisco Square like the Frisco Farmers Market, Music In the Square, Christmas in the Square, Arts in the Square, and more. We also have tons of sporting events, city events like Frisco StrEATS, live music, and a variety of events at local businesses. Got an event you want on Lifestyle Frisco?"}]'

# %% [markdown]
# ### Get things running end to end
# In the following cells, we will define some functions essential for assistants with function calling. All these functions come together in our final cell, where we will define a new web search assistant, give it instructions on its functionality and ask a question.

# %%
def poll_run_till_completion(
    client: AzureOpenAI,
    thread_id: str,
    run_id: str,
    available_functions: dict,
    verbose: bool,
    max_steps: int = 20,
    wait: int = 3,
) -> None:
    """
    Poll a run until it is completed or failed or exceeds a certain number of iterations (MAX_STEPS)
    with a preset wait in between polls

    @param client: OpenAI client
    @param thread_id: Thread ID
    @param run_id: Run ID
    @param assistant_id: Assistant ID
    @param verbose: Print verbose output
    @param max_steps: Maximum number of steps to poll
    @param wait: Wait time in seconds between polls

    """

    if (client is None and thread_id is None) or run_id is None:
        print("Client, Thread ID and Run ID are required.")
        return
    try:
        cnt = 0
        while cnt < max_steps:
            run = client.beta.threads.runs.retrieve(thread_id=thread_id, run_id=run_id)
            if verbose:
                print("Poll {}: {}".format(cnt, run.status))
            cnt += 1
            if run.status == "requires_action":
                tool_responses = []
                if (
                    run.required_action.type == "submit_tool_outputs"
                    and run.required_action.submit_tool_outputs.tool_calls is not None
                ):
                    tool_calls = run.required_action.submit_tool_outputs.tool_calls

                    for call in tool_calls:
                        if call.type == "function":
                            if call.function.name not in available_functions:
                                raise Exception("Function requested by the model does not exist")
                            function_to_call = available_functions[call.function.name]
                            tool_response = function_to_call(**json.loads(call.function.arguments))
                            tool_responses.append({"tool_call_id": call.id, "output": tool_response})

                run = client.beta.threads.runs.submit_tool_outputs(
                    thread_id=thread_id, run_id=run.id, tool_outputs=tool_responses
                )
            if run.status == "failed":
                print("Run failed.")
                break
            if run.status == "completed":
                break
            time.sleep(wait)

    except Exception as e:
        print(e)

# %%
def create_message(
    client: AzureOpenAI,
    thread_id: str,
    role: str = "",
    content: str = "",
    file_ids: Optional[list] = None,
    metadata: Optional[dict] = None,
    message_id: Optional[str] = None,
) -> any:
    """
    Create a message in a thread using the client.

    @param client: OpenAI client
    @param thread_id: Thread ID
    @param role: Message role (user or assistant)
    @param content: Message content
    @param file_ids: Message file IDs
    @param metadata: Message metadata
    @param message_id: Message ID
    @return: Message object

    """
    if metadata is None:
        metadata = {}
    if file_ids is None:
        file_ids = []

    if client is None:
        print("Client parameter is required.")
        return None

    if thread_id is None:
        print("Thread ID is required.")
        return None

    try:
        if message_id is not None:
            return client.beta.threads.messages.retrieve(thread_id=thread_id, message_id=message_id)

        if file_ids is not None and len(file_ids) > 0 and metadata is not None and len(metadata) > 0:
            return client.beta.threads.messages.create(
                thread_id=thread_id, role=role, content=content, file_ids=file_ids, metadata=metadata
            )

        if file_ids is not None and len(file_ids) > 0:
            return client.beta.threads.messages.create(
                thread_id=thread_id, role=role, content=content, file_ids=file_ids
            )

        if metadata is not None and len(metadata) > 0:
            return client.beta.threads.messages.create(
                thread_id=thread_id, role=role, content=content, metadata=metadata
            )

        return client.beta.threads.messages.create(thread_id=thread_id, role=role, content=content)

    except Exception as e:
        print(e)
        return None

# %%
def retrieve_and_print_messages(
    client: AzureOpenAI, thread_id: str, verbose: bool, out_dir: Optional[str] = None
) -> any:
    """
    Retrieve a list of messages in a thread and print it out with the query and response

    @param client: OpenAI client
    @param thread_id: Thread ID
    @param verbose: Print verbose output
    @param out_dir: Output directory to save images
    @return: Messages object

    """

    if client is None and thread_id is None:
        print("Client and Thread ID are required.")
        return None
    try:
        messages = client.beta.threads.messages.list(thread_id=thread_id)
        display_role = {"user": "User query", "assistant": "Assistant response"}

        prev_role = None

        if verbose:
            print("\n\nCONVERSATION:")
        for md in reversed(messages.data):
            if prev_role == "assistant" and md.role == "user" and verbose:
                print("------ \n")

            for mc in md.content:
                # Check if valid text field is present in the mc object
                if mc.type == "text":
                    txt_val = mc.text.value
                # Check if valid image field is present in the mc object
                elif mc.type == "image_file":
                    image_data = client.files.content(mc.image_file.file_id)
                    if out_dir is not None:
                        out_dir_path = Path(out_dir)
                        if out_dir_path.exists():
                            image_path = out_dir_path / (mc.image_file.file_id + ".png")
                            with image_path.open("wb") as f:
                                f.write(image_data.read())

                if verbose:
                    if prev_role == md.role:
                        print(txt_val)
                    else:
                        print("{}:\n{}".format(display_role[md.role], txt_val))
            prev_role = md.role
        return messages
    except Exception as e:
        print(e)
        return None

# %%
name = "websearch-assistant"
instructions = """You are a helpful assistant who helps me dress appropriately for the weather. Please provide me a fashiaionable outfit. Please use multiple tools at your disposal.
You have access to query the web using Bing Search and also you have access to get real time temperature from weather a api. 
You should call bing search to fetch me the current events.
"""

message = {"role": "user", "content": "Can you suggest weather appropriate attire with the recommended events in Madrid, Spain?"}


tools = [
{
                "type": "function",
                "function": {
                    "name": "weather",
                    "description": "Get the weather for a city in celsius",
                    "parameters": {
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA"
                            },
                            "unit": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"]
                            }
                        },
                        "required": ["location"]
                    }
                }},
        {   
                "type": "function",
                 "function": {                   
                    "name": "get_topevents",
                    "description": "Search and Retrieve latest events happening in the city.",
                    "parameters": {
                        "type": "object",
                        "properties": {
                            "query": {
                                "type": "string",
                                "description": "The query string to search the events. e.g. Top events in Frisco today.",
                            }
                        },
                        "required": ["query"]
                    }
                }
           } 
]

available_functions = {"weather": weather,"get_topevents": get_topevents}

verbose_output = True

client = AzureOpenAI(api_key=aoai_api_key, api_version=api_version, azure_endpoint=azure_endpoint)

assistant = client.beta.assistants.create(
    name=name, description="", instructions=instructions, tools=tools, model=deployment_name
)

thread = client.beta.threads.create()
create_message(client, thread.id, message["role"], message["content"])


run = client.beta.threads.runs.create(thread_id=thread.id, assistant_id=assistant.id, instructions=instructions)
poll_run_till_completion(
    client=client, thread_id=thread.id, run_id=run.id, available_functions=available_functions, verbose=verbose_output
)
messages = retrieve_and_print_messages(client=client, thread_id=thread.id, verbose=verbose_output)
# Out:
# Poll 0: queued
# Poll 1: requires_action
# Lat: 40.41669, Lon: -3.70035
# 12
# Poll 2: requires_action
# Poll 3: in_progress
# Poll 4: in_progress
# Poll 5: in_progress
# Poll 6: in_progress
# Poll 7: in_progress
# Poll 8: in_progress
# Poll 9: in_progress
# Poll 10: completed
#
#
# CONVERSATION:
# User query:
# Can you suggest weather appropriate attire with the recommended events in Madrid, Spain?
# Assistant response:
# Based on the current temperature of 12 celsius in Madrid, Spain, I'd suggest the following fashionable yet weather-appropriate attire:
#
# - A lightweight cashmere or wool blend sweater: Given the crisp weather, it would provide the necessary warmth. You could opt for a neutral color like gray or navy-blue for versatility.
# - A pair of slim-fit chinos: Opt for something lightweight and comfortable, like a tan or olive-color, which pairs well with a variety of tops.
# - Layered with a light jacket: A denim or a leather jacket would add a fashionable edge to your outfit without adding too much bulk.
# - Close-toed shoes: A pair of loafers or ankle boots will keep your feet warm and stylish.
#
# As per events happening in Madrid today, considering different interests, here are a few options:
#
# - **Immersive Exhibition**: The Last Days of Pompeii event allows you to discover the life and customs of the rising power of the Roman Empire at Matadero Madrid. Tickets are on sale until 7 April.
# - **Fashion and NFTs**: El trabajo de Gucci y Adidas event at The Social Hub Madrid by 7:30 PM. This could be an interesting event if you're into fashion and technology.
# - **Music Concert**: Delinquent Habits+Sick Jacken performing at Changó Club at 10:00 AM tomorrow.
# - **Dinner and Drinks**: You can pick from the top restaurants and bars in Madrid for an extraordinary dining experience.
# - **Cultural Offerings** If you're into performances and exhibitions, check out IFEMA MADRID's events taking place today.
#
# Be sure to check the details and protocols for each event before you go. Enjoy your day in Madrid!

# %%
thread_messages = client.beta.threads.messages.list(thread.id)
print(thread_messages.model_dump_json(indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "msg_TUc9K7t5kAaMqwcoao5RavOz",
#       "assistant_id": "asst_iYwIdBKudu6UZ5uToTvq4C6g",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Based on the current temperature of 12 celsius in Madrid, Spain, I'd suggest the following fashionable yet weather-appropriate attire:\n\n- A lightweight cashmere or wool blend sweater: Given the crisp weather, it would provide the necessary warmth. You could opt for a neutral color like gray or navy-blue for versatility.\n- A pair of slim-fit chinos: Opt for something lightweight and comfortable, like a tan or olive-color, which pairs well with a variety of tops.\n- Layered with a light jacket: A denim or a leather jacket would add a fashionable edge to your outfit without adding too much bulk.\n- Close-toed shoes: A pair of loafers or ankle boots will keep your feet warm and stylish.\n\nAs per events happening in Madrid today, considering different interests, here are a few options:\n\n- **Immersive Exhibition**: The Last Days of Pompeii event allows you to discover the life and customs of the rising power of the Roman Empire at Matadero Madrid. Tickets are on sale until 7 April.\n- **Fashion and NFTs**: El trabajo de Gucci y Adidas event at The Social Hub Madrid by 7:30 PM. This could be an interesting event if you're into fashion and technology.\n- **Music Concert**: Delinquent Habits+Sick Jacken performing at Changó Club at 10:00 AM tomorrow.\n- **Dinner and Drinks**: You can pick from the top restaurants and bars in Madrid for an extraordinary dining experience.\n- **Cultural Offerings** If you're into performances and exhibitions, check out IFEMA MADRID's events taking place today.\n\nBe sure to check the details and protocols for each event before you go. Enjoy your day in Madrid!"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708026976,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_CfpjhFyAOlZkYJmQJ13nmvNu",
#       "thread_id": "thread_60fIXS2cM6rg6xIzQPVp8nWa"
#     },
#     {
#       "id": "msg_2YjjYDiE3otBvWZ1rOcmuseA",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Can you suggest weather appropriate attire with the recommended events in Madrid, Spain?"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708026963,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_60fIXS2cM6rg6xIzQPVp8nWa"
#     }
#   ],
#   "object": "list",
#   "first_id": "msg_TUc9K7t5kAaMqwcoao5RavOz",
#   "last_id": "msg_2YjjYDiE3otBvWZ1rOcmuseA",
#   "has_more": false
# }

# %%
assistant = client.beta.assistants.create(
    name="Data Visualization",
    instructions=f"You are a helpful AI assistant who makes interesting visualizations based on data." 
    f"You have access to a sandboxed environment for writing and testing code."
    f"When you are asked to create a visualization you should follow these steps:"
    f"1. Write the code."
    f"2. Anytime you write new code display a preview of the code to show your work."
    f"3. Run the code to confirm that it runs."
    f"4. If the code is successful display the visualization."
    f"5. If the code is unsuccessful display the error message and try to revise the code and rerun going through the steps from above again.",
    tools=[{"type": "code_interpreter"}],
    model=deployment_name #You must replace this value with the deployment name for your model.
)

# %%
print(assistant.model_dump_json(indent=2))
# Out:
# {
#   "id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#   "created_at": 1708028581,
#   "description": null,
#   "file_ids": [],
#   "instructions": "You are a helpful AI assistant who makes interesting visualizations based on data.You have access to a sandboxed environment for writing and testing code.When you are asked to create a visualization you should follow these steps:1. Write the code.2. Anytime you write new code display a preview of the code to show your work.3. Run the code to confirm that it runs.4. If the code is successful display the visualization.5. If the code is unsuccessful display the error message and try to revise the code and rerun going through the steps from above again.",
#   "metadata": {},
#   "model": "gpt-4-32k",
#   "name": "Data Visualization",
#   "object": "assistant",
#   "tools": [
#     {
#       "type": "code_interpreter"
#     }
#   ]
# }

# %%
# Create a thread
thread = client.beta.threads.create()
print(thread)
# Out:
# Thread(id='thread_4CoQ7WnycY4x1Q0etBFd3LzP', created_at=1708028622, metadata={}, object='thread')

# %%
# Add a user question to the thread
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="Create a visualization of a sinewave"
)

# %%
thread_messages = client.beta.threads.messages.list(thread.id)
print(thread_messages.model_dump_json(indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Create a visualization of a sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028678,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     }
#   ],
#   "object": "list",
#   "first_id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#   "last_id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#   "has_more": false
# }

# %%
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
  #instructions="New instructions" #You can optionally provide new instructions but these will override the default instructions
)

# %%
# Retrieve the status of the run
run = client.beta.threads.runs.retrieve(
  thread_id=thread.id,
  run_id=run.id
)

status = run.status
print(status)
# Out:
# in_progress

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)

print(messages.model_dump_json(indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "msg_DTeR3HAIx6TQGkINoWjJ6bgx",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "image_file": {
#             "file_id": "assistant-iFyHrcLyBTs5OIKh06tCeWCZ"
#           },
#           "type": "image_file"
#         },
#         {
#           "text": {
#             "annotations": [],
#             "value": "Here is the visualization of a sine wave. You can see the typical wave-like pattern, which is characteristic of a sine function. In this plot, the x-axis represents the input values ranging from -10 to +10, and the y-axis represents the output of the sine function for these input values."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028756,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_pDq386WWLTyjCflNLqFCSKK0",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Okay, let's generate some data for a sine wave first. We can use the numpy package for generating the wave and matplotlib for plotting it. Here is the Python code for that: \n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.plot(x, y)\nplt.show()\n```\nLet's generate the plot now."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028727,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Create a visualization of a sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028678,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     }
#   ],
#   "object": "list",
#   "first_id": "msg_DTeR3HAIx6TQGkINoWjJ6bgx",
#   "last_id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#   "has_more": false
# }

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)
data = json.loads(messages.model_dump_json(indent=2))  # Load JSON data into a Python object
image_file_id = data['data'][0]['content'][0]['image_file']['file_id']

print(image_file_id)  # Outputs: assistant-1YGVTvNzc2JXajI5JU9F0HMD
# Out:
# assistant-iFyHrcLyBTs5OIKh06tCeWCZ

# %%
content = client.files.content(image_file_id)

image= content.write_to_file("sinewave.png")

# %%
from PIL import Image

# Display the image in the default image viewer
image = Image.open("sinewave.png")
image.show()

# %%
# Add a new user question to the thread
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="Show me the code you used to generate the sinewave"
)

# %%
# Add a new user question to the thread
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="Show me the code you used to generate the sinewave"
)
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
  #instructions="New instructions" #You can optionally provide new instructions  but these will override the default instructions
)

# Retrieve the status of the run
run = client.beta.threads.runs.retrieve(
  thread_id=thread.id,
  run_id=run.id
)

status = run.status
print(status)
# Out:
# in_progress

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)

print(messages.model_dump_json(indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "msg_v2Pgy5pRR9Yk8XzRBWvT6jE2",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Certainly, here's the Python code I used to generate that sine wave:\n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.figure(figsize=(8, 6))\nplt.plot(x, y)\nplt.title('Sine Wave')\nplt.xlabel('X')\nplt.ylabel('Y')\nplt.grid(True)\nplt.show()\n```\n\nThis code does the following:\n\n1. Imports the necessary libraries (numpy for numerical operations and matplotlib for plotting).\n\n2. Generates a sequence of 1000 numbers evenly spaced between -10 and 10.\n\n3. Calculates the sine of each of these numbers, resulting in a numpy array (essentially creating the y-values for our plot).\n\n4. Defines the size of the plot.\n\n5. Defines the data to be plotted (x-values versus y-values).\n\n6. Sets the title of the plot and the labels of x and y axes.\n\n7. Displays grid lines.\n\n8. Displays the plot."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029328,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_hygNlfgasghC6x1iOdPypBd5",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_8CmjNrSa1adfasjYAY6REOBa",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Show me the code you used to generate the sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029285,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_DTeR3HAIx6TQGkINoWjJ6bgx",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "image_file": {
#             "file_id": "assistant-iFyHrcLyBTs5OIKh06tCeWCZ"
#           },
#           "type": "image_file"
#         },
#         {
#           "text": {
#             "annotations": [],
#             "value": "Here is the visualization of a sine wave. You can see the typical wave-like pattern, which is characteristic of a sine function. In this plot, the x-axis represents the input values ranging from -10 to +10, and the y-axis represents the output of the sine function for these input values."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028756,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_pDq386WWLTyjCflNLqFCSKK0",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Okay, let's generate some data for a sine wave first. We can use the numpy package for generating the wave and matplotlib for plotting it. Here is the Python code for that: \n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.plot(x, y)\nplt.show()\n```\nLet's generate the plot now."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028727,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Create a visualization of a sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028678,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     }
#   ],
#   "object": "list",
#   "first_id": "msg_v2Pgy5pRR9Yk8XzRBWvT6jE2",
#   "last_id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#   "has_more": false
# }

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)

print(messages.model_dump_json(indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "msg_v2Pgy5pRR9Yk8XzRBWvT6jE2",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Certainly, here's the Python code I used to generate that sine wave:\n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.figure(figsize=(8, 6))\nplt.plot(x, y)\nplt.title('Sine Wave')\nplt.xlabel('X')\nplt.ylabel('Y')\nplt.grid(True)\nplt.show()\n```\n\nThis code does the following:\n\n1. Imports the necessary libraries (numpy for numerical operations and matplotlib for plotting).\n\n2. Generates a sequence of 1000 numbers evenly spaced between -10 and 10.\n\n3. Calculates the sine of each of these numbers, resulting in a numpy array (essentially creating the y-values for our plot).\n\n4. Defines the size of the plot.\n\n5. Defines the data to be plotted (x-values versus y-values).\n\n6. Sets the title of the plot and the labels of x and y axes.\n\n7. Displays grid lines.\n\n8. Displays the plot."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029328,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_hygNlfgasghC6x1iOdPypBd5",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_8CmjNrSa1adfasjYAY6REOBa",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Show me the code you used to generate the sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029285,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_DTeR3HAIx6TQGkINoWjJ6bgx",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "image_file": {
#             "file_id": "assistant-iFyHrcLyBTs5OIKh06tCeWCZ"
#           },
#           "type": "image_file"
#         },
#         {
#           "text": {
#             "annotations": [],
#             "value": "Here is the visualization of a sine wave. You can see the typical wave-like pattern, which is characteristic of a sine function. In this plot, the x-axis represents the input values ranging from -10 to +10, and the y-axis represents the output of the sine function for these input values."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028756,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_pDq386WWLTyjCflNLqFCSKK0",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Okay, let's generate some data for a sine wave first. We can use the numpy package for generating the wave and matplotlib for plotting it. Here is the Python code for that: \n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.plot(x, y)\nplt.show()\n```\nLet's generate the plot now."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028727,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Create a visualization of a sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028678,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     }
#   ],
#   "object": "list",
#   "first_id": "msg_v2Pgy5pRR9Yk8XzRBWvT6jE2",
#   "last_id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#   "has_more": false
# }

# %%
data = json.loads(messages.model_dump_json(indent=2))
code = data['data'][0]['content'][0]['text']['value']
print(code)
# Out:
# Certainly, here's the Python code I used to generate that sine wave:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate a sequence of numbers from -10 to 10 with 1000 steps in between
# x = np.linspace(-10, 10, 1000)
# # Create a second array using sine
# y = np.sin(x)
#
# plt.figure(figsize=(8, 6))
# plt.plot(x, y)
# plt.title('Sine Wave')
# plt.xlabel('X')
# plt.ylabel('Y')
# plt.grid(True)
# plt.show()
# ```
#
# This code does the following:
#
# 1. Imports the necessary libraries (numpy for numerical operations and matplotlib for plotting).
#
# 2. Generates a sequence of 1000 numbers evenly spaced between -10 and 10.
#
# 3. Calculates the sine of each of these numbers, resulting in a numpy array (essentially creating the y-values for our plot).
#
# 4. Defines the size of the plot.
#
# 5. Defines the data to be plotted (x-values versus y-values).
#
# 6. Sets the title of the plot and the labels of x and y axes.
#
# 7. Displays grid lines.
#
# 8. Displays the plot.

# %%
# Add a user question to the thread
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="I prefer visualizations in darkmode can you change the colors to make a darkmode version of this visualization."
)

# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
)

# Retrieve the status of the run
run = client.beta.threads.runs.retrieve(
  thread_id=thread.id,
  run_id=run.id
)

status = run.status
print(status)
# Out:
# queued

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)

print(messages.model_dump_json(indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "msg_lB5TE4NWJCPlxnvBJSWHrp4Y",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "image_file": {
#             "file_id": "assistant-RBDLnxCYbkpDSSr8RDPJpkzs"
#           },
#           "type": "image_file"
#         },
#         {
#           "text": {
#             "annotations": [],
#             "value": "Here is the visualization of a sine wave in dark mode. The x-axis represents the input values ranging from -10 to +10, and the y-axis represents the output of the sine function for these input values. The sine wave is colored cyan on the dark background for better visibility."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029444,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_bOnHLwg2myCQHOLTuC8c59V1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_cGwhgoMgDWWUmzwcJjJdn7WU",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Sure, we can adjust the plot style to a dark background using Matplotlib's built-in style sheets. We will use 'dark_background' for this purpose. Here's the updated code:\n\n```python\nplt.style.use('dark_background')\n\nplt.figure(figsize=(8, 6))\nplt.plot(x, y, color=\"cyan\")\nplt.title('Sine Wave')\nplt.xlabel('X')\nplt.ylabel('Y')\nplt.grid(color = \"gray\")\nplt.show()\n```\n\nLet's generate the plot in dark mode."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029426,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_bOnHLwg2myCQHOLTuC8c59V1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_KkyDDmksHMcB6GZzSuYJsokt",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "I prefer visualizations in darkmode can you change the colors to make a darkmode version of this visualization."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029424,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_v2Pgy5pRR9Yk8XzRBWvT6jE2",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Certainly, here's the Python code I used to generate that sine wave:\n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.figure(figsize=(8, 6))\nplt.plot(x, y)\nplt.title('Sine Wave')\nplt.xlabel('X')\nplt.ylabel('Y')\nplt.grid(True)\nplt.show()\n```\n\nThis code does the following:\n\n1. Imports the necessary libraries (numpy for numerical operations and matplotlib for plotting).\n\n2. Generates a sequence of 1000 numbers evenly spaced between -10 and 10.\n\n3. Calculates the sine of each of these numbers, resulting in a numpy array (essentially creating the y-values for our plot).\n\n4. Defines the size of the plot.\n\n5. Defines the data to be plotted (x-values versus y-values).\n\n6. Sets the title of the plot and the labels of x and y axes.\n\n7. Displays grid lines.\n\n8. Displays the plot."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029328,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_hygNlfgasghC6x1iOdPypBd5",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_8CmjNrSa1adfasjYAY6REOBa",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Show me the code you used to generate the sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029285,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_DTeR3HAIx6TQGkINoWjJ6bgx",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "image_file": {
#             "file_id": "assistant-iFyHrcLyBTs5OIKh06tCeWCZ"
#           },
#           "type": "image_file"
#         },
#         {
#           "text": {
#             "annotations": [],
#             "value": "Here is the visualization of a sine wave. You can see the typical wave-like pattern, which is characteristic of a sine function. In this plot, the x-axis represents the input values ranging from -10 to +10, and the y-axis represents the output of the sine function for these input values."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028756,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_pDq386WWLTyjCflNLqFCSKK0",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Okay, let's generate some data for a sine wave first. We can use the numpy package for generating the wave and matplotlib for plotting it. Here is the Python code for that: \n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.plot(x, y)\nplt.show()\n```\nLet's generate the plot now."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028727,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Create a visualization of a sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028678,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     }
#   ],
#   "object": "list",
#   "first_id": "msg_lB5TE4NWJCPlxnvBJSWHrp4Y",
#   "last_id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#   "has_more": false
# }

# %%
data = json.loads(messages.model_dump_json(indent=2))  # Load JSON data into a Python object
image_file_id = data['data'][0]['content'][0]['image_file']['file_id'] # index numbers can vary if you have had a different conversation over the course of the thread.

print(image_file_id)

content = client.files.content(image_file_id)
image= content.write_to_file("dark_sine.png")

# Display the image in the default image viewer
image = Image.open("dark_sine.png")
image.show()
# Out:
# assistant-RBDLnxCYbkpDSSr8RDPJpkzs

# %%
# Add a new user question to the thread
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="Show me the code you used to generate the sinewave"
)
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
  #instructions="New instructions" #You can optionally provide new instructions  but these will override the default instructions
)

# Retrieve the status of the run
run = client.beta.threads.runs.retrieve(
  thread_id=thread.id,
  run_id=run.id
)

status = run.status
print(status)
# Out:
# queued

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)

print(messages.model_dump_json(indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "msg_nkGFX8BV6KF5Zt7r5LgKtnwW",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Absolutely, here is the Python code used to generate the dark mode version of the sine wave:\n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\n# use a dark background\nplt.style.use('dark_background')\n\nplt.figure(figsize=(8, 6))\nplt.plot(x, y, color=\"cyan\")\nplt.title('Sine Wave', color=\"white\")\nplt.xlabel('X', color=\"white\")\nplt.ylabel('Y', color=\"white\")\nplt.grid(color = \"gray\")\nplt.show()\n```\nThis code is very similar to our previous version, but with added statements to choose a dark background style, modify the color of the plot and the color of the labels to fit the dark theme."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029652,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_E52VSOdG6y6Tgo5DUmOcyLzF",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_F7YC3nw2pt7VmMOptg1ktFGH",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Show me the code you used to generate the sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029650,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_lB5TE4NWJCPlxnvBJSWHrp4Y",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "image_file": {
#             "file_id": "assistant-RBDLnxCYbkpDSSr8RDPJpkzs"
#           },
#           "type": "image_file"
#         },
#         {
#           "text": {
#             "annotations": [],
#             "value": "Here is the visualization of a sine wave in dark mode. The x-axis represents the input values ranging from -10 to +10, and the y-axis represents the output of the sine function for these input values. The sine wave is colored cyan on the dark background for better visibility."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029444,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_bOnHLwg2myCQHOLTuC8c59V1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_cGwhgoMgDWWUmzwcJjJdn7WU",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Sure, we can adjust the plot style to a dark background using Matplotlib's built-in style sheets. We will use 'dark_background' for this purpose. Here's the updated code:\n\n```python\nplt.style.use('dark_background')\n\nplt.figure(figsize=(8, 6))\nplt.plot(x, y, color=\"cyan\")\nplt.title('Sine Wave')\nplt.xlabel('X')\nplt.ylabel('Y')\nplt.grid(color = \"gray\")\nplt.show()\n```\n\nLet's generate the plot in dark mode."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029426,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_bOnHLwg2myCQHOLTuC8c59V1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_KkyDDmksHMcB6GZzSuYJsokt",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "I prefer visualizations in darkmode can you change the colors to make a darkmode version of this visualization."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029424,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_v2Pgy5pRR9Yk8XzRBWvT6jE2",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Certainly, here's the Python code I used to generate that sine wave:\n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.figure(figsize=(8, 6))\nplt.plot(x, y)\nplt.title('Sine Wave')\nplt.xlabel('X')\nplt.ylabel('Y')\nplt.grid(True)\nplt.show()\n```\n\nThis code does the following:\n\n1. Imports the necessary libraries (numpy for numerical operations and matplotlib for plotting).\n\n2. Generates a sequence of 1000 numbers evenly spaced between -10 and 10.\n\n3. Calculates the sine of each of these numbers, resulting in a numpy array (essentially creating the y-values for our plot).\n\n4. Defines the size of the plot.\n\n5. Defines the data to be plotted (x-values versus y-values).\n\n6. Sets the title of the plot and the labels of x and y axes.\n\n7. Displays grid lines.\n\n8. Displays the plot."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029328,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_hygNlfgasghC6x1iOdPypBd5",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_8CmjNrSa1adfasjYAY6REOBa",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Show me the code you used to generate the sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708029285,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_DTeR3HAIx6TQGkINoWjJ6bgx",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "image_file": {
#             "file_id": "assistant-iFyHrcLyBTs5OIKh06tCeWCZ"
#           },
#           "type": "image_file"
#         },
#         {
#           "text": {
#             "annotations": [],
#             "value": "Here is the visualization of a sine wave. You can see the typical wave-like pattern, which is characteristic of a sine function. In this plot, the x-axis represents the input values ranging from -10 to +10, and the y-axis represents the output of the sine function for these input values."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028756,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_pDq386WWLTyjCflNLqFCSKK0",
#       "assistant_id": "asst_TYLk6NRdvxYsrSrQJLmPyE6B",
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Okay, let's generate some data for a sine wave first. We can use the numpy package for generating the wave and matplotlib for plotting it. Here is the Python code for that: \n\n```python\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Generate a sequence of numbers from -10 to 10 with 1000 steps in between\nx = np.linspace(-10, 10, 1000)\n# Create a second array using sine\ny = np.sin(x)\n\nplt.plot(x, y)\nplt.show()\n```\nLet's generate the plot now."
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028727,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "assistant",
#       "run_id": "run_7MahoQMStgR5aTzmrYg0VFX1",
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     },
#     {
#       "id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#       "assistant_id": null,
#       "content": [
#         {
#           "text": {
#             "annotations": [],
#             "value": "Create a visualization of a sinewave"
#           },
#           "type": "text"
#         }
#       ],
#       "created_at": 1708028678,
#       "file_ids": [],
#       "metadata": {},
#       "object": "thread.message",
#       "role": "user",
#       "run_id": null,
#       "thread_id": "thread_4CoQ7WnycY4x1Q0etBFd3LzP"
#     }
#   ],
#   "object": "list",
#   "first_id": "msg_nkGFX8BV6KF5Zt7r5LgKtnwW",
#   "last_id": "msg_zxc7uRxpdNBWWmE1r0o5PMpY",
#   "has_more": false
# }

# %%
data = json.loads(messages.model_dump_json(indent=2))
code = data['data'][0]['content'][0]['text']['value']
print(code)
# Out:
# Absolutely, here is the Python code used to generate the dark mode version of the sine wave:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate a sequence of numbers from -10 to 10 with 1000 steps in between
# x = np.linspace(-10, 10, 1000)
# # Create a second array using sine
# y = np.sin(x)
#
# # use a dark background
# plt.style.use('dark_background')
#
# plt.figure(figsize=(8, 6))
# plt.plot(x, y, color="cyan")
# plt.title('Sine Wave', color="white")
# plt.xlabel('X', color="white")
# plt.ylabel('Y', color="white")
# plt.grid(color = "gray")
# plt.show()
# ```
# This code is very similar to our previous version, but with added statements to choose a dark background style, modify the color of the plot and the color of the labels to fit the dark theme.
